# %%
import imageio

# %%
# Read the GIF file
gif = imageio.mimread('/mnt/home/tudomlumleart/ceph/01_ChromatinEnsembleRefinement/chromatin-ensemble-refinement/figures/20240819/The_Horse_in_Motion-anim.gif')

# Display or manipulate frames
for i, frame in enumerate(gif):
    print(f"Displaying frame {i}")
    imageio.imwrite(f"frame_{i}.png", frame)  # Save each frame as a PNG image
# Out:
# Displaying frame 0
# Displaying frame 1
# Displaying frame 2
# Displaying frame 3
# Displaying frame 4
# Displaying frame 5
# Displaying frame 6
# Displaying frame 7
# Displaying frame 8
# Displaying frame 9
# Displaying frame 10

# %%
save_dir = '/mnt/home/tudomlumleart/ceph/01_ChromatinEnsembleRefinement/chromatin-ensemble-refinement/figures/20240819'
import os

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(gif[0], cmap='gray')

# %%
import numpy as np

# %%
# Mean structure
plt.imshow(np.mean(gif, axis=0), cmap='gray')
plt.savefig(os.path.join(save_dir, 'mean_structure.png'))
